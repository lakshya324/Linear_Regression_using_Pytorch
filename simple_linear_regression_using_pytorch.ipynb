# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshya324/Linear_Regression_using_Pytorch/blob/main/simple_linear_regression_using_pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Simple Linear Regression using Pytorch

# %%
import torch
import torch.nn as nn

# %%
from sklearn.datasets import make_regression

# %%
data=make_regression(n_samples=2000,
                     n_features=10,
                     n_informative=8,
                     n_targets=1,
                     random_state=1)
print(data[0].shape)
print(data[1].shape)
# Out:
# (2000, 10)
# (2000,)

# %%
x=torch.from_numpy(data[0]).float()
y=torch.from_numpy(data[1].reshape(-1,1)).float()

# %%
layer1=nn.Linear(10,1)

# %%
loss_fn=nn.MSELoss()#Mean-Square Error
optimizer=torch.optim.SGD(layer1.parameters(),lr=0.01)#Stochastic Gradient Descent

# %%
epochs=100
losses=[]
for epoch in range(epochs):
  y_pred=layer1(x)
  loss=loss_fn(y_pred,y)
  losses.append(loss.detach().numpy())
  optimizer.zero_grad()
  loss.backward()
  optimizer.step()

# %%
import matplotlib.pyplot as plt
plt.plot(losses)
plt.show()
